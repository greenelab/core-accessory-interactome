# %% [markdown]
# # Build reference transcriptome
#
# The first step to using Salmon to get gene expression data is to build a reference transcriptome to align our sample reads against.
#
# **Goal:** To create an index to evaluate sequences for all possible unique sequences of length k in the target transcriptome
#
# **Input:**
#
# Target transcriptome. This transcriptome is given in the form of a multi-FASTA file, with each entry providing the sequence of a transcript. For prokaryotes, transcripts and genes have a more 1-1 mapping so we're using genes for our reference transcriptome and so we don't need to use tximport to map transcript quants to genes.
#
# *What is the relationship between a gene vs transcript?* A gene is a bounded region of a chromosome within which transcription occurs. The gene (DNA sequence) is transcribed into RNA transcript. In bacteria, these RNA transcripts act as mRNA that can be translated into protein. In eukaryotes, the transcript RNA is pre-mRNA and must undergo additional processing (post-transcriptional modifications) before it can be translated. This processing includes addition of a protective cap and tail, splicing to remove introns. So genes can have multiple mRNA (which can encode different proteins) through the process of alternative splicing, where fragments of the pre-mRNA are assembled in different ways.
#
# **Output:**
#
# Quasi-index over the reference transcriptome, which is a structure that salmon uses to quasi-map RNA-seq reads during quantification. The index is a signature for each transcript in the reference transcriptome
#
# The index contains:
# * Suffix array (SA) of the reference transcriptome. There is a suffix array per transcript in the reference, containing a sorted array of all the suffixes of each transcript
# * A hash table mapping each k-mer occurring in the reference transcriptome to its location in SA
# * https://hbctraining.github.io/Intro-to-rnaseq-hpc-O2/lessons/08_salmon.html
#
# **Command:**
#
# `> ./bin/salmon index -t transcripts.fa -i transcripts_index --decoys decoys.txt -k 31`
# * k = minimum acceptable length for valid matches. So a smaller k might improve sensitivity. They found that k=31 works well for reads of 75bp or longer.
# * decoys = Set of target transcript ids that will not appear in the quantification. This decoy transcriptome is meant to mitigate potential spurious mapping of reads that actually arise from some unannotated genomic locus that is sequence-similar to an annotated transcriptome.
#
#
# **Note:** Here we are using [Salmon](https://combine-lab.github.io/salmon/) version 0.11.2 to be consistent with the version running on Dartmouth's computing cluster (Discovery), which is where the data will be processed.

# %%
# %load_ext autoreload
# %autoreload 2

from core_acc_modules import paths

# %%
# Get PAO1 index
! salmon index -t $paths.PAO1_PHAGE_REF -i $paths.PAO1_PHAGE_INDEX
# Out:
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# index ["/home/alexandra/Documents/Data/Core_accessory/pao1_phage_index"] did not previously exist  . . . creating it
# [2021-01-22 19:31:31.731] [jLog] [info] building index
# RapMap Indexer
#
# [Step 1 of 4] : counting k-mers
# [2021-01-22 19:31:31.896] [jointLog] [warning] Entry with header [MT701590.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:31.938] [jointLog] [warning] Entry with header [NC_048170.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:31.942] [jointLog] [warning] Entry with header [MK327938.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:31.967] [jointLog] [warning] Entry with header [NC_019401.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:31.973] [jointLog] [warning] Entry with header [JN882285.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.051] [jointLog] [warning] Entry with header [NC_019526.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.057] [jointLog] [warning] Entry with header [JQ513383.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.130] [jointLog] [warning] Entry with header [NC_007623.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.152] [jointLog] [warning] Entry with header [MK817115.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.170] [jointLog] [warning] Entry with header [AJ697969.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.221] [jointLog] [warning] Entry with header [NC_010821.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.271] [jointLog] [warning] Entry with header [EU197055.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.305] [jointLog] [warning] Entry with header [NC_017972.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.326] [jointLog] [warning] Entry with header [JQ768459.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.365] [jointLog] [warning] Entry with header [NC_016571.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.407] [jointLog] [warning] Entry with header [JN627160.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.454] [jointLog] [warning] Entry with header [NC_041994.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.472] [jointLog] [warning] Entry with header [MF063068.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.541] [jointLog] [warning] Entry with header [MK552327.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.570] [jointLog] [warning] Entry with header [MF042360.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.640] [jointLog] [warning] Entry with header [NC_031245.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.644] [jointLog] [warning] Entry with header [KT624200.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.990] [jointLog] [warning] Entry with header [NC_023557.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:32.995] [jointLog] [warning] Entry with header [KF806589.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.022] [jointLog] [warning] Entry with header [MT708547.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.026] [jointLog] [warning] Entry with header [NC_041884.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.031] [jointLog] [warning] Entry with header [KU935715.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.046] [jointLog] [warning] Entry with header [NC_048792.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.052] [jointLog] [warning] Entry with header [MK994515.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.092] [jointLog] [warning] Entry with header [MN131137.2] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.119] [jointLog] [warning] Entry with header [MN102098.2] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.130] [jointLog] [warning] Entry with header [NC_005260.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.166] [jointLog] [warning] Entry with header [MN453779.2] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.170] [jointLog] [warning] Entry with header [MN032614.2] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.172] [jointLog] [warning] Entry with header [pdb|4ANG|S], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:31:33.172] [jointLog] [warning] Entry with header [pdb|4ANG|R], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:31:33.176] [jointLog] [warning] Entry with header [MT028491.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.196] [jointLog] [warning] Entry with header [MK774614.2] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.216] [jointLog] [warning] Entry with header [pdb|4A8Q|H], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:31:33.216] [jointLog] [warning] Entry with header [pdb|4A8Q|G], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:31:33.216] [jointLog] [warning] Entry with header [pdb|4A8Q|F], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:31:33.216] [jointLog] [warning] Entry with header [pdb|4A8M|B], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:31:33.257] [jointLog] [warning] Entry with header [AY266303.2] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.264] [jointLog] [warning] Entry with header [JX997158.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.268] [jointLog] [warning] Entry with header [pdb|2JLG|F], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:31:33.268] [jointLog] [warning] Entry with header [pdb|2JLG|E], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:31:33.268] [jointLog] [warning] Entry with header [pdb|2JLG|D], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:31:33.276] [jointLog] [warning] Entry with header [JX997179.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.285] [jointLog] [warning] Entry with header [NC_007346.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.290] [jointLog] [warning] Entry with header [JX997160.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.296] [jointLog] [warning] Entry with header [JX997157.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.304] [jointLog] [warning] Entry with header [AJ890364.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:31:33.307] [jointLog] [warning] Entry with header [LP855972.1], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:31:33.307] [jointLog] [warning] Entry with header [LP855971.1], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# Elapsed time: 1.57571s
#
# [2021-01-22 19:31:33.308] [jointLog] [warning] Removed 510 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-22 19:31:33.308] [jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# Replaced 8979 non-ATCG nucleotides
# Clipped poly-A tails from 3 transcripts
# Building rank-select dictionary and saving to disk done
# Elapsed time: 0.00331993s
# Writing sequence data to file . . . done
# Elapsed time: 0.0310718s
# [info] Building 32-bit suffix array (length of generalized text is 60718359)
# Building suffix array . . . success
# saving to disk . . . done
# Elapsed time: 0.0972567s
# done
# Elapsed time: 4.86207s
# processed 60000000 positions
# khash had 37047310 keys
# saving hash to disk . . . done
# Elapsed time: 2.55567s
# [2021-01-22 19:32:11.952] [jLog] [info] done building index

# %%
# Get PA14 index
! salmon index -t $paths.PA14_PHAGE_REF -i $paths.PA14_PHAGE_INDEX
# Out:
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# index ["/home/alexandra/Documents/Data/Core_accessory/pa14_phage_index"] did not previously exist  . . . creating it
# [2021-01-22 19:32:12.108] [jLog] [info] building index
# RapMap Indexer
#
# [Step 1 of 4] : counting k-mers
# [2021-01-22 19:32:12.305] [jointLog] [warning] Entry with header [MT701590.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.347] [jointLog] [warning] Entry with header [NC_048170.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.351] [jointLog] [warning] Entry with header [MK327938.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.375] [jointLog] [warning] Entry with header [NC_019401.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.381] [jointLog] [warning] Entry with header [JN882285.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.459] [jointLog] [warning] Entry with header [NC_019526.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.465] [jointLog] [warning] Entry with header [JQ513383.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.535] [jointLog] [warning] Entry with header [NC_007623.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.557] [jointLog] [warning] Entry with header [MK817115.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.571] [jointLog] [warning] Entry with header [AJ697969.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.620] [jointLog] [warning] Entry with header [NC_010821.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.668] [jointLog] [warning] Entry with header [EU197055.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.701] [jointLog] [warning] Entry with header [NC_017972.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.721] [jointLog] [warning] Entry with header [JQ768459.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.755] [jointLog] [warning] Entry with header [NC_016571.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.796] [jointLog] [warning] Entry with header [JN627160.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.843] [jointLog] [warning] Entry with header [NC_041994.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.860] [jointLog] [warning] Entry with header [MF063068.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.926] [jointLog] [warning] Entry with header [MK552327.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:12.955] [jointLog] [warning] Entry with header [MF042360.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.021] [jointLog] [warning] Entry with header [NC_031245.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.025] [jointLog] [warning] Entry with header [KT624200.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.349] [jointLog] [warning] Entry with header [NC_023557.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.354] [jointLog] [warning] Entry with header [KF806589.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.380] [jointLog] [warning] Entry with header [MT708547.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.384] [jointLog] [warning] Entry with header [NC_041884.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.389] [jointLog] [warning] Entry with header [KU935715.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.403] [jointLog] [warning] Entry with header [NC_048792.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.409] [jointLog] [warning] Entry with header [MK994515.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.448] [jointLog] [warning] Entry with header [MN131137.2] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.475] [jointLog] [warning] Entry with header [MN102098.2] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.486] [jointLog] [warning] Entry with header [NC_005260.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.521] [jointLog] [warning] Entry with header [MN453779.2] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.525] [jointLog] [warning] Entry with header [MN032614.2] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.527] [jointLog] [warning] Entry with header [pdb|4ANG|S], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:32:13.527] [jointLog] [warning] Entry with header [pdb|4ANG|R], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:32:13.532] [jointLog] [warning] Entry with header [MT028491.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.552] [jointLog] [warning] Entry with header [MK774614.2] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.570] [jointLog] [warning] Entry with header [pdb|4A8Q|H], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:32:13.570] [jointLog] [warning] Entry with header [pdb|4A8Q|G], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:32:13.570] [jointLog] [warning] Entry with header [pdb|4A8Q|F], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:32:13.570] [jointLog] [warning] Entry with header [pdb|4A8M|B], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:32:13.582] [jointLog] [warning] Entry with header [AY266303.2] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.590] [jointLog] [warning] Entry with header [JX997158.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.594] [jointLog] [warning] Entry with header [pdb|2JLG|F], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:32:13.594] [jointLog] [warning] Entry with header [pdb|2JLG|E], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:32:13.594] [jointLog] [warning] Entry with header [pdb|2JLG|D], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:32:13.601] [jointLog] [warning] Entry with header [JX997179.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.610] [jointLog] [warning] Entry with header [NC_007346.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.641] [jointLog] [warning] Entry with header [JX997160.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.647] [jointLog] [warning] Entry with header [JX997157.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.655] [jointLog] [warning] Entry with header [AJ890364.1] was longer than 200000 nucleotides.  Are you certain that we are indexing a transcriptome and not a genome?
# [2021-01-22 19:32:13.658] [jointLog] [warning] Entry with header [LP855972.1], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-22 19:32:13.658] [jointLog] [warning] Entry with header [LP855971.1], had length less than the k-mer length of 31 (perhaps after poly-A clipping)
# Elapsed time: 1.5502s
#
# [2021-01-22 19:32:13.659] [jointLog] [warning] Removed 490 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-22 19:32:13.659] [jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# Replaced 8141 non-ATCG nucleotides
# Clipped poly-A tails from 3 transcripts
# Building rank-select dictionary and saving to disk done
# Elapsed time: 0.00287256s
# Writing sequence data to file . . . done
# Elapsed time: 0.0249393s
# [info] Building 32-bit suffix array (length of generalized text is 59320458)
# Building suffix array . . . success
# saving to disk . . . done
# Elapsed time: 0.11345s
# done
# Elapsed time: 4.87383s
# processed 59000000 positions
# khash had 36964624 keys
# saving hash to disk . . . done
# Elapsed time: 2.84644s
# [2021-01-22 19:32:52.790] [jLog] [info] done building index

# %% [markdown]
# **Thoughts based on output:**
# * Since phage entries are genomes instead of genes we are getting a warning message from Salmon: `Entry with header [NC_028999.1] was longer than 200000 nucleotides.  This is probably a chromosome instead of a transcript.` Is Salmon including these entries?
#
# * When building the index I'm getting that PAO1+phage 510 duplicates are removed, PA14+phage 490 duplicates are removed. Previously when we had separate indexes for PAO1, PA14 and phage we got: PAO1 34 duplicates are removed, PA14 37 duplicates are removed, Phage 391 duplicates removed. So the duplicates seem to be mainly an issue with the phage sequences. I'm not sure if these duplicates are expected?

# %% [markdown]
# # Align and quantify samples
#
# The second step is to align our samples against our built index and quantify reads. This notebook aligns a pilot set of samples against the PAO1, PA14 and and PAO1 reference genomes.
#
# **Input:**
# * Index of reference transcriptome
# * FASTQ of experimental samples
#
# **Output:**
# * For each query (fragment), the reference sequences (transcripts), strand and position from which the query may have likely originated. In many cases, this mapping information is sufficient for downstream analysis like transcript quantification
# * Each sample will have a quantification file (called quant.sf). The TSV file will contain the name (Name) of each transcript, its length (Length), effective length (EffectiveLength), and its abundance in terms of Transcripts Per Million (TPM) and estimated number of reads (NumReads) originating from this transcript.
#   * The first two columns are self-explanatory, the name of the transcript and the length of the transcript in base pairs (bp).
#   * The effective length represents the various factors that effect the length of transcript (i.e degradation, technical limitations of the sequencing platform)
#   * Salmon outputs ‘pseudocounts’ which predict the relative abundance of different isoforms in the form of three possible metrics (KPKM, RPKM, and TPM). TPM (transcripts per million) is a commonly used normalization method as described in [1] and is computed based on the effective length of the transcript.
#   * Estimated number of reads (an estimate of the number of reads drawn from this transcript given the transcript’s relative abundance and length)
#
# **Algorithm:**
# * Given the index and a set of sequenced reads, the quant command quasi-maps the reads and uses the resulting mapping information to estimate transcript abundances.
# * Quasi-map is a way to map sequenced fragments (single or paired-end reads) to a target transcriptome. Quasi-mapping produces what we refer to as fragment mapping information. In particular, it provides, for each query (fragment), the reference sequences (transcripts), strand and position from which the query may have likely originated. In many cases, this mapping information is sufficient for downstream analysis like quantification.
#
# Basic steps:
# 1. Scan read until k-mer appears in the hash table
# 2. Look up all SA intervals (reference suffixes) containing that k-mer
# 3. Maximum mappable prefix (MMP) finds the longest read sequence that exactly matches the reference suffix
# 4. Determine the next informative position (NIP) by a k-mer skipping approach
# 5. Repeat until the end of the read
# 6. Reports all MMPs that read intersected with
#
# https://hbctraining.github.io/Intro-to-rnaseq-hpc-O2/lessons/08_salmon.html
#
# **Command:**
#
# Command and parameters:
#
# `> ./bin/salmon quant -i transcripts_index -l <LIBTYPE> -1 reads1.fq -2 reads2.fq --validateMappings -o transcripts_quant`
#
# * libtype = Determines how the reads should be interpreted including the relative orientation of paired ends (inward, outward, matching) and strandedness (stranded=specify if read1 comes from forward or reverse strand, unstranded). Currently using “A” which lets Salmon automatically decide
#   * https://salmon.readthedocs.io/en/latest/salmon.html
#   * (pg 38) https://buildmedia.readthedocs.org/media/pdf/salmon/stable/salmon.pdf
# * What does strand bias in output mean? Strand_bias is such that a value of 0.5 means there is no bias (i.e. half of the fragments start with read 1 on the forward strand and half start with read 1 on the reverse complement strand).
#   * Based on lib_format_counts.json file, the bias is very close to 0.5, just above
#   * https://hbctraining.github.io/Intro-to-rnaseq-hpc-O2/lessons/08_salmon.html

# %%
# %load_ext autoreload
# %autoreload 2

import os
import shutil
import pandas as pd
import numpy as np
from core_acc_modules import paths

np.random.seed(123)

# %% [markdown]
# ### Quantify gene expression
# Now that we have our index built and all of our data downloaded, we’re ready to quantify our samples
#
# **For each sample we have read counts per gene (where the genes are based on the reference gene file provided above).**
#
# Note about TPM calculation:
# * For sample A, transcript X will have read count
# * Reads per kilobase (RPK) = read count/length of the transcript
# * Per million scaling factor = sum(read count/length across all samples for that transcript)/1M
# * TPM = RPK/per million scaling factor
# * TPM will depend on the scaling factor. If the number of mapped reads is very low then scale factor will be very low and so any trancript that mapped will be increased to create outliers since we’re dividing by a small scale factor
#
# **How are paired-end vs single-end read samples treated?**
# * The multiple files are treated as a single library, meaning?? In this case we are not specifying
#
# How are we reading the fastq files to be quantified? Are we reading in all files if multipler are provided?

# %% [markdown]
# #### Get quants using PAO1 reference

# %%
os.makedirs(paths.PAO1_QUANT, exist_ok=True)

# %%
# %%bash -s $paths.PAO1_QUANT $paths.FASTQ_DIR $paths.PAO1_INDEX
#
# for FILE_PATH in $2/*;
# do
#
# # get file name
# sample_name=`basename ${FILE_PATH}`
#
# # remove extension from file name
# sample_name="${sample_name%_*}"
#
# # get base path
# base_name=${FILE_PATH%/*}
#
# echo "Processing sample ${base_name}/${sample_name}/*"
#
# salmon quant -i $3 \
#              -l A \
#              -r ${base_name}/${sample_name}/* \
#              -o $1/${sample_name}_quant
# done
# Out:
# Processing sample /home/alexandra/ncbi/public/fastq_phage/ERR3642743/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/ERR3642743/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/ERR3642743/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13160334/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13160334/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13160334/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13234437/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13234437/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13234437/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pao1_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_1.fastq /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pao1/ERR3642743_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pao1/ERR3642743_quant/logs
# [2021-01-15 18:09:45.929] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:09:45.929] [jointLog] [info] parsing read library format
# [2021-01-15 18:09:45.929] [jointLog] [info] There is 1 library.
# [2021-01-15 18:09:45.976] [stderrLog] [info] Loading Suffix Array
# [2021-01-15 18:09:45.976] [jointLog] [info] Loading Quasi index
# [2021-01-15 18:09:45.976] [jointLog] [info] Loading 32-bit quasi index
# [2021-01-15 18:09:45.987] [stderrLog] [info] Loading Transcript Info
# [2021-01-15 18:09:45.990] [stderrLog] [info] Loading Rank-Select Bit Array
# [2021-01-15 18:09:45.991] [stderrLog] [info] There were 5685 set bits in the bit array
# [2021-01-15 18:09:45.991] [stderrLog] [info] Computing transcript lengths
# [2021-01-15 18:09:45.991] [stderrLog] [info] Waiting to finish loading hash
#
#
#
#
# processed 500000 fragments
# hits: 393147; hits per frag:  0.815945[2021-01-15 18:09:46.282] [jointLog] [info] done
# [2021-01-15 18:09:46.282] [jointLog] [info] Index contained 5685 targets
# [2021-01-15 18:09:46.363] [jointLog] [info] Automatically detected most likely library type as SR
# [2021-01-15 18:09:46.282] [stderrLog] [info] Done loading index
# processed 1000002 fragments
# processed 1500000 fragments
# processed 2000001 fragments
# processed 2500001 fragments
# processed 3000001 fragments
# processed 3500001 fragments
# processed 4000000 fragments
# processed 4500001 fragments
# processed 5000001 fragments
# processed 5500000 fragments
# processed 6000000 fragments
# processed 6500002 fragments
# processed 7000000 fragments
# processed 7500001 fragments
# processed 8000001 fragments
# processed 8500001 fragments
# processed 9000001 fragments
# processed 9500001 fragments
# processed 10000000 fragments
# processed 10500001 fragments
# processed 11000001 fragments
# processed 11500001 fragments
# processed 12000002 fragments
# processed 12500001 fragments
# processed 13000000 fragments
# processed 13500000 fragments
# processed 14000001 fragments
# processed 14500000 fragments
# processed 15000000 fragments
# processed 15500000 fragments
# processed 16000002 fragments
# processed 16500000 fragments
# processed 17000000 fragments
# processed 17500001 fragments
# processed 18000000 fragments
# processed 18500000 fragments
# processed 19000001 fragments
# processed 19500003 fragments
# processed 20000001 fragments
# processed 20500000 fragments
# processed 21000000 fragments
# processed 21500002 fragments
# processed 22000000 fragments
# processed 22500001 fragments
# processed 23000001 fragments
# processed 23500000 fragments
# processed 24000001 fragments
# processed 24500000 fragments
# processed 25000001 fragments
# processed 25500000 fragments
# processed 26000000 fragments
# processed 26500001 fragments
# processed 27000001 fragments
# processed 27500001 fragments
# processed 28000001 fragments
# processed 28500002 fragments
# processed 29000001 fragments
# processed 29500001 fragments
# processed 30000000 fragments
# processed 30500001 fragments
# processed 31000001 fragments
# processed 31500000 fragments
# processed 32000001 fragments
# processed 32500001 fragments
# processed 33000000 fragments
# processed 33500000 fragments
# processed 34000001 fragments
# processed 34500001 fragments
# processed 35000000 fragments
# processed 35500001 fragments
# processed 36000002 fragments
# processed 36500000 fragments
# processed 37000001 fragments
# processed 37500000 fragments
# processed 38000000 fragments
# processed 38500001 fragments
# processed 39000000 fragments
# processed 39500000 fragments
# processed 40000000 fragments
# processed 40500000 fragments
# processed 41000000 fragments
# processed 41500001 fragments
# processed 42000001 fragments
# processed 42500000 fragments
# processed 43000000 fragments
# processed 43500001 fragments
# processed 44000002 fragments
# processed 44500002 fragments
# processed 45000000 fragments
# processed 45500000 fragments
# processed 46000000 fragments
# processed 46500000 fragments
# processed 47000000 fragments
# processed 47500000 fragments
# processed 48000001 fragments
# hits: 36713353; hits per frag:  0.765921
#
#
#
#
#
#
#
# [2021-01-15 18:10:11.508] [jointLog] [info] Thread saw mini-batch with a maximum of 59.40% zero probability fragments
# [2021-01-15 18:10:11.510] [jointLog] [info] Thread saw mini-batch with a maximum of 58.56% zero probability fragments
# [2021-01-15 18:10:11.511] [jointLog] [info] Thread saw mini-batch with a maximum of 58.91% zero probability fragments
# [2021-01-15 18:10:11.512] [jointLog] [info] Thread saw mini-batch with a maximum of 60.56% zero probability fragments
# [2021-01-15 18:10:11.515] [jointLog] [info] Thread saw mini-batch with a maximum of 58.96% zero probability fragments
# [2021-01-15 18:10:11.515] [jointLog] [info] Thread saw mini-batch with a maximum of 60.37% zero probability fragments
# [2021-01-15 18:10:11.525] [jointLog] [info] Computed 5638 rich equivalence classes for further processing
# [2021-01-15 18:10:11.525] [jointLog] [info] Counted 15808318 total reads in the equivalence classes
# [2021-01-15 18:10:11.527] [jointLog] [info] Mapping rate = 32.8027%
#
# [2021-01-15 18:10:11.527] [jointLog] [info] finished quantifyLibrary()
# [2021-01-15 18:10:11.527] [jointLog] [info] Starting optimizer
# [2021-01-15 18:10:11.528] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2021-01-15 18:10:11.529] [jointLog] [info] iteration = 0 | max rel diff. = 1469.05
# [2021-01-15 18:10:11.545] [jointLog] [info] iteration = 100 | max rel diff. = 0.00702689
# [2021-01-15 18:10:11.545] [jointLog] [info] Finished optimizer
# [2021-01-15 18:10:11.545] [jointLog] [info] writing output
#
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pao1_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_1.fastq /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pao1/ERR3642743_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pao1/ERR3642743_quant/logs
# [2021-01-15 18:10:12.456] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:10:12.456] [jointLog] [info] parsing read library format
# [2021-01-15 18:10:12.456] [jointLog] [info] There is 1 library.
# [2021-01-15 18:10:12.501] [stderrLog] [info] Loading Suffix Array
# [2021-01-15 18:10:12.501] [jointLog] [info] Loading Quasi index
# [2021-01-15 18:10:12.501] [jointLog] [info] Loading 32-bit quasi index
# [2021-01-15 18:10:12.512] [stderrLog] [info] Loading Transcript Info
# [2021-01-15 18:10:12.515] [stderrLog] [info] Loading Rank-Select Bit Array
# [2021-01-15 18:10:12.515] [stderrLog] [info] There were 5685 set bits in the bit array
# [2021-01-15 18:10:12.516] [stderrLog] [info] Computing transcript lengths
# [2021-01-15 18:10:12.516] [stderrLog] [info] Waiting to finish loading hash
#
#
#
#
# processed 500000 fragments
# hits: 393133; hits per frag:  0.810101[2021-01-15 18:10:12.805] [jointLog] [info] done
# [2021-01-15 18:10:12.805] [jointLog] [info] Index contained 5685 targets
# [2021-01-15 18:10:12.884] [jointLog] [info] Automatically detected most likely library type as SR
# [2021-01-15 18:10:12.805] [stderrLog] [info] Done loading index
# processed 1000001 fragments
# processed 1500001 fragments
# processed 2000000 fragments
# processed 2500000 fragments
# processed 3000001 fragments
# processed 3500000 fragments
# processed 4000000 fragments
# processed 4500001 fragments
# processed 5000000 fragments
# processed 5500002 fragments
# processed 6000000 fragments
# processed 6500001 fragments
# processed 7000000 fragments
# processed 7500001 fragments
# processed 8000000 fragments
# processed 8500000 fragments
# processed 9000001 fragments
# processed 9500002 fragments
# processed 10000002 fragments
# processed 10500002 fragments
# processed 11000002 fragments
# processed 11500003 fragments
# processed 12000001 fragments
# processed 12500001 fragments
# processed 13000000 fragments
# processed 13500000 fragments
# processed 14000000 fragments
# processed 14500000 fragments
# processed 15000000 fragments
# processed 15500003 fragments
# processed 16000001 fragments
# processed 16500001 fragments
# processed 17000000 fragments
# processed 17500000 fragments
# processed 18000001 fragments
# processed 18500001 fragments
# processed 19000001 fragments
# processed 19500001 fragments
# processed 20000000 fragments
# processed 20500000 fragments
# processed 21000000 fragments
# processed 21500002 fragments
# processed 22000000 fragments
# processed 22500000 fragments
# processed 23000002 fragments
# processed 23500002 fragments
# processed 24000000 fragments
# processed 24500001 fragments
# processed 25000001 fragments
# processed 25500002 fragments
# processed 26000000 fragments
# processed 26500000 fragments
# processed 27000003 fragments
# processed 27500000 fragments
# processed 28000000 fragments
# processed 28500000 fragments
# processed 29000000 fragments
# processed 29500001 fragments
# processed 30000001 fragments
# processed 30500001 fragments
# processed 31000000 fragments
# processed 31500001 fragments
# processed 32000001 fragments
# processed 32500000 fragments
# processed 33000002 fragments
# processed 33500000 fragments
# processed 34000000 fragments
# processed 34500000 fragments
# processed 35000000 fragments
# processed 35500000 fragments
# processed 36000000 fragments
# processed 36500002 fragments
# processed 37000000 fragments
# processed 37500000 fragments
# processed 38000001 fragments
# processed 38500000 fragments
# processed 39000004 fragments
# processed 39500002 fragments
# processed 40000001 fragments
# processed 40500000 fragments
# processed 41000002 fragments
# processed 41500002 fragments
# processed 42000000 fragments
# processed 42500002 fragments
# processed 43000000 fragments
# processed 43500001 fragments
# processed 44000001 fragments
# processed 44500001 fragments
# processed 45000001 fragments
# processed 45500001 fragments
# processed 46000000 fragments
# processed 46500001 fragments
# processed 47000000 fragments
# processed 47500000 fragments
# processed 48000001 fragments
# hits: 36713370; hits per frag:  0.765096
#
#
#
#
#
#
#
# [2021-01-15 18:10:35.533] [jointLog] [info] Thread saw mini-batch with a maximum of 59.59% zero probability fragments
# [2021-01-15 18:10:35.537] [jointLog] [info] Thread saw mini-batch with a maximum of 59.21% zero probability fragments
# [2021-01-15 18:10:35.539] [jointLog] [info] Thread saw mini-batch with a maximum of 60.27% zero probability fragments
# [2021-01-15 18:10:35.541] [jointLog] [info] Thread saw mini-batch with a maximum of 59.69% zero probability fragments
# [2021-01-15 18:10:35.543] [jointLog] [info] Thread saw mini-batch with a maximum of 59.11% zero probability fragments
# [2021-01-15 18:10:35.545] [jointLog] [info] Thread saw mini-batch with a maximum of 58.53% zero probability fragments
# [2021-01-15 18:10:35.555] [jointLog] [info] Computed 5638 rich equivalence classes for further processing
# [2021-01-15 18:10:35.555] [jointLog] [info] Counted 15808689 total reads in the equivalence classes
# [2021-01-15 18:10:35.557] [jointLog] [info] Mapping rate = 32.8035%
#
# [2021-01-15 18:10:35.557] [jointLog] [info] finished quantifyLibrary()
# [2021-01-15 18:10:35.557] [jointLog] [info] Starting optimizer
# [2021-01-15 18:10:35.559] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2021-01-15 18:10:35.559] [jointLog] [info] iteration = 0 | max rel diff. = 1469.06
# [2021-01-15 18:10:35.574] [jointLog] [info] iteration = 100 | max rel diff. = 0.0070263
# [2021-01-15 18:10:35.575] [jointLog] [info] Finished optimizer
# [2021-01-15 18:10:35.575] [jointLog] [info] writing output
#
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pao1_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_1.fastq /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pao1/ERR3642743_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pao1/ERR3642743_quant/logs
# [2021-01-15 18:10:36.482] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:10:36.482] [jointLog] [info] parsing read library format
# [2021-01-15 18:10:36.482] [jointLog] [info] There is 1 library.
# [2021-01-15 18:10:36.527] [stderrLog] [info] Loading Suffix Array
# [2021-01-15 18:10:36.527] [jointLog] [info] Loading Quasi index
# [2021-01-15 18:10:36.527] [jointLog] [info] Loading 32-bit quasi index
# [2021-01-15 18:10:36.537] [stderrLog] [info] Loading Transcript Info
# [2021-01-15 18:10:36.541] [stderrLog] [info] Loading Rank-Select Bit Array
# [2021-01-15 18:10:36.541] [stderrLog] [info] There were 5685 set bits in the bit array
# [2021-01-15 18:10:36.542] [stderrLog] [info] Computing transcript lengths
# [2021-01-15 18:10:36.542] [stderrLog] [info] Waiting to finish loading hash
#
#
#
#
# processed 500000 fragments
# hits: 393130; hits per frag:  0.797087[2021-01-15 18:10:36.830] [jointLog] [info] done
# [2021-01-15 18:10:36.830] [jointLog] [info] Index contained 5685 targets
# [2021-01-15 18:10:36.910] [jointLog] [info] Automatically detected most likely library type as SR
# [2021-01-15 18:10:36.830] [stderrLog] [info] Done loading index
# processed 1000000 fragments
# processed 1500001 fragments
# processed 2000000 fragments
# processed 2500000 fragments
# processed 3000000 fragments
# processed 3500001 fragments
# processed 4000000 fragments
# processed 4500000 fragments
# processed 5000000 fragments
# processed 5500001 fragments
# processed 6000000 fragments
# processed 6500001 fragments
# processed 7000001 fragments
# processed 7500001 fragments
# processed 8000000 fragments
# processed 8500000 fragments
# processed 9000000 fragments
# processed 9500001 fragments
# processed 10000001 fragments
# processed 10500000 fragments
# processed 11000001 fragments
# processed 11500000 fragments
# processed 12000000 fragments
# processed 12500001 fragments
# processed 13000000 fragments
# processed 13500001 fragments
# processed 14000002 fragments
# processed 14500000 fragments
# processed 15000002 fragments
# processed 15500002 fragments
# processed 16000000 fragments
# processed 16500001 fragments
# processed 17000000 fragments
# processed 17500000 fragments
# processed 18000001 fragments
# processed 18500000 fragments
# processed 19000000 fragments
# processed 19500002 fragments
# processed 20000001 fragments
# processed 20500001 fragments
# processed 21000000 fragments
# processed 21500001 fragments
# processed 22000000 fragments
# processed 22500000 fragments
# processed 23000002 fragments
# processed 23500000 fragments
# processed 24000000 fragments
# processed 24500000 fragments
# processed 25000000 fragments
# processed 25500002 fragments
# processed 26000001 fragments
# processed 26500000 fragments
# processed 27000000 fragments
# processed 27500000 fragments
# processed 28000001 fragments
# processed 28500000 fragments
# processed 29000001 fragments
# processed 29500003 fragments
# processed 30000001 fragments
# processed 30500001 fragments
# processed 31000000 fragments
# processed 31500000 fragments
# processed 32000000 fragments
# processed 32500000 fragments
# processed 33000000 fragments
# processed 33500002 fragments
# processed 34000000 fragments
# processed 34500000 fragments
# processed 35000000 fragments
# processed 35500000 fragments
# processed 36000003 fragments
# processed 36500001 fragments
# processed 37000002 fragments
# processed 37500000 fragments
# processed 38000002 fragments
# processed 38500000 fragments
# processed 39000002 fragments
# processed 39500001 fragments
# processed 40000001 fragments
# processed 40500001 fragments
# processed 41000000 fragments
# processed 41500001 fragments
# processed 42000001 fragments
# processed 42500001 fragments
# processed 43000000 fragments
# processed 43500002 fragments
# processed 44000002 fragments
# processed 44500000 fragments
# processed 45000000 fragments
# processed 45500000 fragments
# processed 46000001 fragments
# processed 46500000 fragments
# processed 47000001 fragments
# processed 47500000 fragments
# processed 48000002 fragments
# hits: 36713451; hits per frag:  0.764902
#
#
#
#
#
#
#
# [2021-01-15 18:10:59.452] [jointLog] [info] Thread saw mini-batch with a maximum of 59.01% zero probability fragments
# [2021-01-15 18:10:59.453] [jointLog] [info] Thread saw mini-batch with a maximum of 58.82% zero probability fragments
# [2021-01-15 18:10:59.453] [jointLog] [info] Thread saw mini-batch with a maximum of 59.04% zero probability fragments
# [2021-01-15 18:10:59.453] [jointLog] [info] Thread saw mini-batch with a maximum of 58.54% zero probability fragments
# [2021-01-15 18:10:59.454] [jointLog] [info] Thread saw mini-batch with a maximum of 60.17% zero probability fragments
# [2021-01-15 18:10:59.456] [jointLog] [info] Thread saw mini-batch with a maximum of 60.08% zero probability fragments
# [2021-01-15 18:10:59.467] [jointLog] [info] Computed 5638 rich equivalence classes for further processing
# [2021-01-15 18:10:59.467] [jointLog] [info] Counted 15809550 total reads in the equivalence classes
# [2021-01-15 18:10:59.469] [jointLog] [info] Mapping rate = 32.8053%
#
# [2021-01-15 18:10:59.469] [jointLog] [info] finished quantifyLibrary()
# [2021-01-15 18:10:59.469] [jointLog] [info] Starting optimizer
# [2021-01-15 18:10:59.470] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2021-01-15 18:10:59.470] [jointLog] [info] iteration = 0 | max rel diff. = 1469.1
# [2021-01-15 18:10:59.485] [jointLog] [info] iteration = 100 | max rel diff. = 0.00704156
# [2021-01-15 18:10:59.485] [jointLog] [info] Finished optimizer
# [2021-01-15 18:10:59.485] [jointLog] [info] writing output
#
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pao1_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pao1/SRR13160334_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pao1/SRR13160334_quant/logs
# [2021-01-15 18:11:00.505] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:11:00.505] [jointLog] [info] parsing read library format
# [2021-01-15 18:11:00.505] [jointLog] [info] There is 1 library.
# [2021-01-15 18:11:00.551] [stderrLog] [info] Loading Suffix Array
# [2021-01-15 18:11:00.551] [jointLog] [info] Loading Quasi index
# [2021-01-15 18:11:00.551] [jointLog] [info] Loading 32-bit quasi index
# [2021-01-15 18:11:00.562] [stderrLog] [info] Loading Transcript Info
# [2021-01-15 18:11:00.565] [stderrLog] [info] Loading Rank-Select Bit Array
# [2021-01-15 18:11:00.566] [stderrLog] [info] There were 5685 set bits in the bit array
# [2021-01-15 18:11:00.566] [stderrLog] [info] Computing transcript lengths
# [2021-01-15 18:11:00.566] [stderrLog] [info] Waiting to finish loading hash
#
#
#
#
# [2021-01-15 18:11:00.854] [jointLog] [info] done
# [2021-01-15 18:11:00.854] [jointLog] [info] Index contained 5685 targets
# [2021-01-15 18:11:00.936] [jointLog] [info] Automatically detected most likely library type as SR
# processed 500001 fragments
# hits: 830721; hits per frag:  1.72131[2021-01-15 18:11:00.854] [stderrLog] [info] Done loading index
# processed 1000002 fragments
# processed 1500000 fragments
# processed 2000000 fragments
# processed 2500000 fragments
# processed 3000000 fragments
# processed 3500000 fragments
# processed 4000000 fragments
# processed 4500000 fragments
# processed 5000002 fragments
# processed 5500000 fragments
# processed 6000001 fragments
# processed 6500000 fragments
# processed 7000000 fragments
# processed 7500000 fragments
# processed 8000000 fragments
# processed 8500000 fragments
# processed 9000002 fragments
# processed 9500000 fragments
# processed 10000000 fragments
# processed 10500001 fragments
# processed 11000000 fragments
# processed 11500000 fragments
# processed 12000002 fragments
# processed 12500000 fragments
# processed 13000001 fragments
# processed 13500001 fragments
# processed 14000001 fragments
# processed 14500000 fragments
# processed 15000000 fragments
# processed 15500000 fragments
# processed 16000002 fragments
# processed 16500000 fragments
# processed 17000003 fragments
# hits: 28517375; hits per frag:  1.67966
#
#
#
#
#
#
#
# [2021-01-15 18:11:12.388] [jointLog] [info] Thread saw mini-batch with a maximum of 75.68% zero probability fragments
# [2021-01-15 18:11:12.389] [jointLog] [info] Thread saw mini-batch with a maximum of 75.46% zero probability fragments
# [2021-01-15 18:11:12.393] [jointLog] [info] Thread saw mini-batch with a maximum of 75.92% zero probability fragments
# [2021-01-15 18:11:12.394] [jointLog] [info] Thread saw mini-batch with a maximum of 75.78% zero probability fragments
# [2021-01-15 18:11:12.395] [jointLog] [info] Thread saw mini-batch with a maximum of 75.66% zero probability fragments
# [2021-01-15 18:11:12.395] [jointLog] [info] Thread saw mini-batch with a maximum of 75.64% zero probability fragments
# [2021-01-15 18:11:12.406] [jointLog] [info] Computed 5472 rich equivalence classes for further processing
# [2021-01-15 18:11:12.406] [jointLog] [info] Counted 6602193 total reads in the equivalence classes
# [2021-01-15 18:11:12.408] [jointLog] [info] Mapping rate = 38.0763%
#
# [2021-01-15 18:11:12.408] [jointLog] [info] finished quantifyLibrary()
# [2021-01-15 18:11:12.408] [jointLog] [info] Starting optimizer
# [2021-01-15 18:11:12.409] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2021-01-15 18:11:12.410] [jointLog] [info] iteration = 0 | max rel diff. = 790.62
# [2021-01-15 18:11:12.424] [jointLog] [info] iteration = 100 | max rel diff. = 0.0050092
# [2021-01-15 18:11:12.424] [jointLog] [info] Finished optimizer
# [2021-01-15 18:11:12.424] [jointLog] [info] writing output
#
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pao1_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pao1/SRR13160334_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pao1/SRR13160334_quant/logs
# [2021-01-15 18:11:13.029] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:11:13.029] [jointLog] [info] parsing read library format
# [2021-01-15 18:11:13.029] [jointLog] [info] There is 1 library.
# [2021-01-15 18:11:13.075] [stderrLog] [info] Loading Suffix Array
# [2021-01-15 18:11:13.075] [jointLog] [info] Loading Quasi index
# [2021-01-15 18:11:13.075] [jointLog] [info] Loading 32-bit quasi index
# [2021-01-15 18:11:13.086] [stderrLog] [info] Loading Transcript Info
# [2021-01-15 18:11:13.089] [stderrLog] [info] Loading Rank-Select Bit Array
# [2021-01-15 18:11:13.089] [stderrLog] [info] There were 5685 set bits in the bit array
# [2021-01-15 18:11:13.090] [stderrLog] [info] Computing transcript lengths
# [2021-01-15 18:11:13.090] [stderrLog] [info] Waiting to finish loading hash
#
#
#
#
# [2021-01-15 18:11:13.379] [jointLog] [info] done
# [2021-01-15 18:11:13.379] [jointLog] [info] Index contained 5685 targets
# [2021-01-15 18:11:13.462] [jointLog] [info] Automatically detected most likely library type as SR
# [2021-01-15 18:11:13.379] [stderrLog] [info] Done loading index
# processed 500000 fragments
# processed 1000001 fragments
# processed 1500001 fragments
# processed 2000000 fragments
# processed 2500000 fragments
# processed 3000001 fragments
# processed 3500000 fragments
# processed 4000000 fragments
# processed 4500000 fragments
# processed 5000000 fragments
# processed 5500001 fragments
# processed 6000000 fragments
# processed 6500001 fragments
# processed 7000000 fragments
# processed 7500002 fragments
# processed 8000000 fragments
# processed 8500001 fragments
# processed 9000002 fragments
# processed 9500000 fragments
# processed 10000002 fragments
# processed 10500000 fragments
# processed 11000002 fragments
# processed 11500002 fragments
# processed 12000000 fragments
# processed 12500000 fragments
# processed 13000000 fragments
# processed 13500000 fragments
# processed 14000001 fragments
# processed 14500000 fragments
# processed 15000000 fragments
# processed 15500001 fragments
# processed 16000000 fragments
# processed 16500003 fragments
# processed 17000001 fragments
# hits: 28517368; hits per frag:  1.67988
#
#
#
#
#
#
#
# [2021-01-15 18:11:24.880] [jointLog] [info] Thread saw mini-batch with a maximum of 75.92% zero probability fragments
# [2021-01-15 18:11:24.880] [jointLog] [info] Thread saw mini-batch with a maximum of 75.48% zero probability fragments
# [2021-01-15 18:11:24.882] [jointLog] [info] Thread saw mini-batch with a maximum of 75.80% zero probability fragments
# [2021-01-15 18:11:24.883] [jointLog] [info] Thread saw mini-batch with a maximum of 75.58% zero probability fragments
# [2021-01-15 18:11:24.884] [jointLog] [info] Thread saw mini-batch with a maximum of 75.68% zero probability fragments
# [2021-01-15 18:11:24.894] [jointLog] [info] Thread saw mini-batch with a maximum of 75.46% zero probability fragments
# [2021-01-15 18:11:24.905] [jointLog] [info] Computed 5472 rich equivalence classes for further processing
# [2021-01-15 18:11:24.905] [jointLog] [info] Counted 6602325 total reads in the equivalence classes
# [2021-01-15 18:11:24.907] [jointLog] [info] Mapping rate = 38.0771%
#
# [2021-01-15 18:11:24.907] [jointLog] [info] finished quantifyLibrary()
# [2021-01-15 18:11:24.907] [jointLog] [info] Starting optimizer
# [2021-01-15 18:11:24.908] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2021-01-15 18:11:24.908] [jointLog] [info] iteration = 0 | max rel diff. = 790.628
# [2021-01-15 18:11:24.923] [jointLog] [info] iteration = 100 | max rel diff. = 0.00501105
# [2021-01-15 18:11:24.923] [jointLog] [info] Finished optimizer
# [2021-01-15 18:11:24.923] [jointLog] [info] writing output
#
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pao1_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pao1/SRR13160334_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pao1/SRR13160334_quant/logs
# [2021-01-15 18:11:25.555] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:11:25.555] [jointLog] [info] parsing read library format
# [2021-01-15 18:11:25.555] [jointLog] [info] There is 1 library.
# [2021-01-15 18:11:25.601] [stderrLog] [info] Loading Suffix Array
# [2021-01-15 18:11:25.600] [jointLog] [info] Loading Quasi index
# [2021-01-15 18:11:25.600] [jointLog] [info] Loading 32-bit quasi index
# [2021-01-15 18:11:25.611] [stderrLog] [info] Loading Transcript Info
# [2021-01-15 18:11:25.614] [stderrLog] [info] Loading Rank-Select Bit Array
# [2021-01-15 18:11:25.615] [stderrLog] [info] There were 5685 set bits in the bit array
# [2021-01-15 18:11:25.615] [stderrLog] [info] Computing transcript lengths
# [2021-01-15 18:11:25.615] [stderrLog] [info] Waiting to finish loading hash
#
#
#
#
# [2021-01-15 18:11:25.904] [jointLog] [info] done
# [2021-01-15 18:11:25.904] [jointLog] [info] Index contained 5685 targets
# [2021-01-15 18:11:25.988] [jointLog] [info] Automatically detected most likely library type as SR
# [2021-01-15 18:11:25.904] [stderrLog] [info] Done loading index
# processed 500000 fragments
# processed 1000002 fragments
# processed 1500000 fragments
# processed 2000000 fragments
# processed 2500001 fragments
# processed 3000001 fragments
# processed 3500000 fragments
# processed 4000000 fragments
# processed 4500000 fragments
# processed 5000001 fragments
# processed 5500000 fragments
# processed 6000000 fragments
# processed 6500000 fragments
# processed 7000000 fragments
# processed 7500000 fragments
# processed 8000001 fragments
# processed 8500000 fragments
# processed 9000001 fragments
# processed 9500000 fragments
# processed 10000000 fragments
# processed 10500001 fragments
# processed 11000000 fragments
# processed 11500000 fragments
# processed 12000002 fragments
# processed 12500001 fragments
# processed 13000001 fragments
# processed 13500001 fragments
# processed 14000001 fragments
# processed 14500001 fragments
# processed 15000001 fragments
# processed 15500000 fragments
# processed 16000000 fragments
# processed 16500001 fragments
# processed 17000000 fragments
# hits: 28517323; hits per frag:  1.67908
#
#
#
#
#
#
#
# [2021-01-15 18:11:37.535] [jointLog] [info] Thread saw mini-batch with a maximum of 75.76% zero probability fragments
# [2021-01-15 18:11:37.535] [jointLog] [info] Thread saw mini-batch with a maximum of 75.70% zero probability fragments
# [2021-01-15 18:11:37.540] [jointLog] [info] Thread saw mini-batch with a maximum of 75.58% zero probability fragments
# [2021-01-15 18:11:37.546] [jointLog] [info] Thread saw mini-batch with a maximum of 75.66% zero probability fragments
# [2021-01-15 18:11:37.547] [jointLog] [info] Thread saw mini-batch with a maximum of 75.66% zero probability fragments
# [2021-01-15 18:11:37.549] [jointLog] [info] Thread saw mini-batch with a maximum of 75.78% zero probability fragments
# [2021-01-15 18:11:37.560] [jointLog] [info] Computed 5472 rich equivalence classes for further processing
# [2021-01-15 18:11:37.560] [jointLog] [info] Counted 6602226 total reads in the equivalence classes
# [2021-01-15 18:11:37.562] [jointLog] [info] Mapping rate = 38.0765%
#
# [2021-01-15 18:11:37.562] [jointLog] [info] finished quantifyLibrary()
# [2021-01-15 18:11:37.562] [jointLog] [info] Starting optimizer
# [2021-01-15 18:11:37.563] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2021-01-15 18:11:37.564] [jointLog] [info] iteration = 0 | max rel diff. = 790.623
# [2021-01-15 18:11:37.578] [jointLog] [info] iteration = 100 | max rel diff. = 0.00500607
# [2021-01-15 18:11:37.578] [jointLog] [info] Finished optimizer
# [2021-01-15 18:11:37.578] [jointLog] [info] writing output
#
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pao1_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pao1/SRR13234437_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pao1/SRR13234437_quant/logs
# [2021-01-15 18:11:38.587] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:11:38.587] [jointLog] [info] parsing read library format
# [2021-01-15 18:11:38.587] [jointLog] [info] There is 1 library.
# [2021-01-15 18:11:38.632] [stderrLog] [info] Loading Suffix Array
# [2021-01-15 18:11:38.632] [jointLog] [info] Loading Quasi index
# [2021-01-15 18:11:38.632] [jointLog] [info] Loading 32-bit quasi index
# [2021-01-15 18:11:38.643] [stderrLog] [info] Loading Transcript Info
# [2021-01-15 18:11:38.646] [stderrLog] [info] Loading Rank-Select Bit Array
# [2021-01-15 18:11:38.646] [stderrLog] [info] There were 5685 set bits in the bit array
# [2021-01-15 18:11:38.647] [stderrLog] [info] Computing transcript lengths
# [2021-01-15 18:11:38.647] [stderrLog] [info] Waiting to finish loading hash
#
#
#
#
# [2021-01-15 18:11:38.935] [jointLog] [info] done
# [2021-01-15 18:11:38.935] [jointLog] [info] Index contained 5685 targets
# [2021-01-15 18:11:38.935] [stderrLog] [info] Done loading index
# processed 500000 fragments
# processed 1000001 fragments
# processed 1500000 fragments
# processed 2000000 fragments
# processed 2500000 fragments
# processed 3000000 fragments
# processed 3500000 fragments
# processed 4000000 fragments
# hits: 49752; hits per frag:  0.0125013[2021-01-15 18:11:51.152] [jointLog] [info] Automatically detected most likely library type as SR
# processed 4500000 fragments
# processed 5000001 fragments
# processed 5500000 fragments
# processed 6000000 fragments
# processed 6500000 fragments
# processed 7000000 fragments
# processed 7500000 fragments
# processed 8000000 fragments
# processed 8500000 fragments
# processed 9000000 fragments
# processed 9500000 fragments
# processed 10000000 fragments
# processed 10500000 fragments
# processed 11000000 fragments
# processed 11500000 fragments
# processed 12000000 fragments
# processed 12500000 fragments
# processed 13000000 fragments
# processed 13500000 fragments
# processed 14000000 fragments
# processed 14500001 fragments
# processed 15000001 fragments
# processed 15500000 fragments
# processed 16000000 fragments
# processed 16500000 fragments
# processed 17000000 fragments
# processed 17500000 fragments
# processed 18000000 fragments
# processed 18500000 fragments
# processed 19000000 fragments
# processed 19500000 fragments
# processed 20000000 fragments
# processed 20500000 fragments
# processed 21000000 fragments
# processed 21500000 fragments
# processed 22000000 fragments
# processed 22500000 fragments
# processed 23000001 fragments
# processed 23500000 fragments
# processed 24000000 fragments
# processed 24500000 fragments
# processed 25000000 fragments
# processed 25500000 fragments
# processed 26000000 fragments
# processed 26500001 fragments
# processed 27000000 fragments
# processed 27500000 fragments
# processed 28000000 fragments
# processed 28500000 fragments
# processed 29000000 fragments
# processed 29500000 fragments
# processed 30000000 fragments
# processed 30500001 fragments
# processed 31000000 fragments
# hits: 385519; hits per frag:  0.0124406
#
#
#
#
#
#
#
# [2021-01-15 18:13:13.924] [jointLog] [info] Thread saw mini-batch with a maximum of 1.12% zero probability fragments
# [2021-01-15 18:13:13.940] [jointLog] [info] Thread saw mini-batch with a maximum of 1.20% zero probability fragments
# [2021-01-15 18:13:13.944] [jointLog] [info] Thread saw mini-batch with a maximum of 1.14% zero probability fragments
# [2021-01-15 18:13:13.952] [jointLog] [info] Thread saw mini-batch with a maximum of 1.22% zero probability fragments
# [2021-01-15 18:13:13.954] [jointLog] [info] Thread saw mini-batch with a maximum of 1.14% zero probability fragments
# [2021-01-15 18:13:13.984] [jointLog] [info] Thread saw mini-batch with a maximum of 1.18% zero probability fragments
# [2021-01-15 18:13:13.993] [jointLog] [info] Computed 551 rich equivalence classes for further processing
# [2021-01-15 18:13:13.993] [jointLog] [info] Counted 106018 total reads in the equivalence classes
# [2021-01-15 18:13:13.996] [jointLog] [warning] Only 106018 fragments were mapped, but the number of burn-in fragments was set to 5000000.
# The effective lengths have been computed using the observed mappings.
#
# [2021-01-15 18:13:13.996] [jointLog] [info] Mapping rate = 0.338223%
#
# [2021-01-15 18:13:13.996] [jointLog] [info] finished quantifyLibrary()
# [2021-01-15 18:13:13.996] [jointLog] [info] Starting optimizer
# [2021-01-15 18:13:13.997] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2021-01-15 18:13:13.997] [jointLog] [info] iteration = 0 | max rel diff. = 10.8273
# [2021-01-15 18:13:14.006] [jointLog] [info] iteration = 100 | max rel diff. = 0.0650826
# [2021-01-15 18:13:14.008] [jointLog] [info] iteration = 118 | max rel diff. = 0.00171978
# [2021-01-15 18:13:14.008] [jointLog] [info] Finished optimizer
# [2021-01-15 18:13:14.008] [jointLog] [info] writing output
#
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pao1_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pao1/SRR13234437_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pao1/SRR13234437_quant/logs
# [2021-01-15 18:13:14.623] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:13:14.623] [jointLog] [info] parsing read library format
# [2021-01-15 18:13:14.623] [jointLog] [info] There is 1 library.
# [2021-01-15 18:13:14.669] [stderrLog] [info] Loading Suffix Array
# [2021-01-15 18:13:14.668] [jointLog] [info] Loading Quasi index
# [2021-01-15 18:13:14.669] [jointLog] [info] Loading 32-bit quasi index
# [2021-01-15 18:13:14.682] [stderrLog] [info] Loading Transcript Info
# [2021-01-15 18:13:14.685] [stderrLog] [info] Loading Rank-Select Bit Array
# [2021-01-15 18:13:14.686] [stderrLog] [info] There were 5685 set bits in the bit array
# [2021-01-15 18:13:14.686] [stderrLog] [info] Computing transcript lengths
# [2021-01-15 18:13:14.686] [stderrLog] [info] Waiting to finish loading hash
#
#
#
#
# [2021-01-15 18:13:14.972] [jointLog] [info] done
# [2021-01-15 18:13:14.972] [jointLog] [info] Index contained 5685 targets
# [2021-01-15 18:13:14.972] [stderrLog] [info] Done loading index
# processed 500001 fragments
# processed 1000000 fragments
# processed 1500000 fragments
# processed 2000002 fragments
# processed 2500000 fragments
# processed 3000000 fragments
# processed 3500000 fragments
# processed 4000000 fragments
# hits: 49753; hits per frag:  0.0125153[2021-01-15 18:13:27.216] [jointLog] [info] Automatically detected most likely library type as SR
# processed 4500000 fragments
# processed 5000001 fragments
# processed 5500001 fragments
# processed 6000000 fragments
# processed 6500000 fragments
# processed 7000000 fragments
# processed 7500001 fragments
# processed 8000000 fragments
# processed 8500000 fragments
# processed 9000001 fragments
# processed 9500000 fragments
# processed 10000000 fragments
# processed 10500000 fragments
# processed 11000000 fragments
# processed 11500000 fragments
# processed 12000000 fragments
# processed 12500000 fragments
# processed 13000000 fragments
# processed 13500000 fragments
# processed 14000000 fragments
# processed 14500000 fragments
# processed 15000000 fragments
# processed 15500001 fragments
# processed 16000000 fragments
# processed 16500001 fragments
# processed 17000000 fragments
# processed 17500000 fragments
# processed 18000000 fragments
# processed 18500000 fragments
# processed 19000000 fragments
# processed 19500000 fragments
# processed 20000000 fragments
# processed 20500000 fragments
# processed 21000000 fragments
# processed 21500000 fragments
# processed 22000000 fragments
# processed 22500000 fragments
# processed 23000000 fragments
# processed 23500000 fragments
# processed 24000000 fragments
# processed 24500000 fragments
# processed 25000000 fragments
# processed 25500000 fragments
# processed 26000003 fragments
# processed 26500000 fragments
# processed 27000000 fragments
# processed 27500000 fragments
# processed 28000001 fragments
# processed 28500000 fragments
# processed 29000000 fragments
# processed 29500000 fragments
# processed 30000001 fragments
# processed 30500000 fragments
# processed 31000000 fragments
# hits: 385528; hits per frag:  0.0124436
#
#
#
#
#
#
#
# [2021-01-15 18:14:49.693] [jointLog] [info] Thread saw mini-batch with a maximum of 1.14% zero probability fragments
# [2021-01-15 18:14:49.699] [jointLog] [info] Thread saw mini-batch with a maximum of 1.30% zero probability fragments
# [2021-01-15 18:14:49.739] [jointLog] [info] Thread saw mini-batch with a maximum of 1.32% zero probability fragments
# [2021-01-15 18:14:49.747] [jointLog] [info] Thread saw mini-batch with a maximum of 1.10% zero probability fragments
# [2021-01-15 18:14:49.749] [jointLog] [info] Thread saw mini-batch with a maximum of 1.28% zero probability fragments
# [2021-01-15 18:14:49.762] [jointLog] [info] Thread saw mini-batch with a maximum of 1.18% zero probability fragments
# [2021-01-15 18:14:49.771] [jointLog] [info] Computed 551 rich equivalence classes for further processing
# [2021-01-15 18:14:49.771] [jointLog] [info] Counted 106016 total reads in the equivalence classes
# [2021-01-15 18:14:49.774] [jointLog] [warning] Only 106016 fragments were mapped, but the number of burn-in fragments was set to 5000000.
# The effective lengths have been computed using the observed mappings.
#
# [2021-01-15 18:14:49.774] [jointLog] [info] Mapping rate = 0.338217%
#
# [2021-01-15 18:14:49.774] [jointLog] [info] finished quantifyLibrary()
# [2021-01-15 18:14:49.774] [jointLog] [info] Starting optimizer
# [2021-01-15 18:14:49.775] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2021-01-15 18:14:49.775] [jointLog] [info] iteration = 0 | max rel diff. = 10.8272
# [2021-01-15 18:14:49.785] [jointLog] [info] iteration = 100 | max rel diff. = 0.0650812
# [2021-01-15 18:14:49.787] [jointLog] [info] iteration = 118 | max rel diff. = 0.0017206
# [2021-01-15 18:14:49.787] [jointLog] [info] Finished optimizer
# [2021-01-15 18:14:49.787] [jointLog] [info] writing output
#
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pao1_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pao1/SRR13234437_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pao1/SRR13234437_quant/logs
# [2021-01-15 18:14:50.208] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:14:50.208] [jointLog] [info] parsing read library format
# [2021-01-15 18:14:50.208] [jointLog] [info] There is 1 library.
# [2021-01-15 18:14:50.263] [stderrLog] [info] Loading Suffix Array
# [2021-01-15 18:14:50.263] [jointLog] [info] Loading Quasi index
# [2021-01-15 18:14:50.263] [jointLog] [info] Loading 32-bit quasi index
# [2021-01-15 18:14:50.274] [stderrLog] [info] Loading Transcript Info
# [2021-01-15 18:14:50.277] [stderrLog] [info] Loading Rank-Select Bit Array
# [2021-01-15 18:14:50.278] [stderrLog] [info] There were 5685 set bits in the bit array
# [2021-01-15 18:14:50.278] [stderrLog] [info] Computing transcript lengths
# [2021-01-15 18:14:50.278] [stderrLog] [info] Waiting to finish loading hash
#
#
#
#
# [2021-01-15 18:14:50.567] [jointLog] [info] done
# [2021-01-15 18:14:50.567] [jointLog] [info] Index contained 5685 targets
# [2021-01-15 18:14:50.567] [stderrLog] [info] Done loading index
# processed 500000 fragments
# processed 1000000 fragments
# processed 1500001 fragments
# processed 2000000 fragments
# processed 2500000 fragments
# processed 3000000 fragments
# processed 3500000 fragments
# processed 4000000 fragments
# hits: 49756; hits per frag:  0.0124651[2021-01-15 18:15:02.774] [jointLog] [info] Automatically detected most likely library type as SR
# processed 4500000 fragments
# processed 5000000 fragments
# processed 5500000 fragments
# processed 6000000 fragments
# processed 6500000 fragments
# processed 7000000 fragments
# processed 7500000 fragments
# processed 8000000 fragments
# processed 8500000 fragments
# processed 9000000 fragments
# processed 9500002 fragments
# processed 10000000 fragments
# processed 10500000 fragments
# processed 11000001 fragments
# processed 11500000 fragments
# processed 12000000 fragments
# processed 12500000 fragments
# processed 13000000 fragments
# processed 13500000 fragments
# processed 14000001 fragments
# processed 14500000 fragments
# processed 15000000 fragments
# processed 15500000 fragments
# processed 16000001 fragments
# processed 16500000 fragments
# processed 17000000 fragments
# processed 17500000 fragments
# processed 18000000 fragments
# processed 18500000 fragments
# processed 19000000 fragments
# processed 19500000 fragments
# processed 20000000 fragments
# processed 20500000 fragments
# processed 21000000 fragments
# processed 21500000 fragments
# processed 22000000 fragments
# processed 22500000 fragments
# processed 23000000 fragments
# processed 23500000 fragments
# processed 24500000 fragments
# processed 25000000 fragments
# processed 25500001 fragments
# processed 26000001 fragments
# processed 26500000 fragments
# processed 27000000 fragments
# processed 27500000 fragments
# processed 28000000 fragments
# processed 28500000 fragments
# processed 29000000 fragments
# processed 29500000 fragments
# processed 30000000 fragments
# processed 30500000 fragments
# processed 31000001 fragments
# hits: 385506; hits per frag:  0.0124438
#
#
#
#
#
#
#
# [2021-01-15 18:16:26.314] [jointLog] [info] Thread saw mini-batch with a maximum of 1.14% zero probability fragments
# [2021-01-15 18:16:26.335] [jointLog] [info] Thread saw mini-batch with a maximum of 1.12% zero probability fragments
# [2021-01-15 18:16:26.341] [jointLog] [info] Thread saw mini-batch with a maximum of 1.22% zero probability fragments
# [2021-01-15 18:16:26.344] [jointLog] [info] Thread saw mini-batch with a maximum of 1.20% zero probability fragments
# [2021-01-15 18:16:26.347] [jointLog] [info] Thread saw mini-batch with a maximum of 1.08% zero probability fragments
# [2021-01-15 18:16:26.365] [jointLog] [info] Thread saw mini-batch with a maximum of 1.21% zero probability fragments
# [2021-01-15 18:16:26.374] [jointLog] [info] Computed 551 rich equivalence classes for further processing
# [2021-01-15 18:16:26.374] [jointLog] [info] Counted 106018 total reads in the equivalence classes
# [2021-01-15 18:16:26.377] [jointLog] [warning] Only 106018 fragments were mapped, but the number of burn-in fragments was set to 5000000.
# The effective lengths have been computed using the observed mappings.
#
# [2021-01-15 18:16:26.377] [jointLog] [info] Mapping rate = 0.338223%
#
# [2021-01-15 18:16:26.377] [jointLog] [info] finished quantifyLibrary()
# [2021-01-15 18:16:26.377] [jointLog] [info] Starting optimizer
# [2021-01-15 18:16:26.378] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2021-01-15 18:16:26.378] [jointLog] [info] iteration = 0 | max rel diff. = 10.8273
# [2021-01-15 18:16:26.388] [jointLog] [info] iteration = 100 | max rel diff. = 0.065082
# [2021-01-15 18:16:26.390] [jointLog] [info] iteration = 118 | max rel diff. = 0.00172011
# [2021-01-15 18:16:26.390] [jointLog] [info] Finished optimizer
# [2021-01-15 18:16:26.390] [jointLog] [info] writing output

# %% [markdown]
# #### Get quants using PA14 reference

# %%
os.makedirs(paths.PA14_QUANT, exist_ok=True)

# %%
# %%bash -s $paths.PA14_QUANT $paths.FASTQ_DIR $paths.PA14_INDEX
#
# for FILE_PATH in $2/*;
# do
#
# # get file name
# sample_name=`basename ${FILE_PATH}`
#
# # remove extension from file name
# sample_name="${sample_name%_*}"
#
# # get base path
# base_name=${FILE_PATH%/*}
#
# echo "Processing sample ${base_name}/${sample_name}/*"
#
# salmon quant -i $3 \
#              -l A \
#              -r ${base_name}/${sample_name}/* \
#              -o $1/${sample_name}_quant
# done
# Out:
# Processing sample /home/alexandra/ncbi/public/fastq_phage/ERR3642743/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/ERR3642743/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/ERR3642743/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13160334/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13160334/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13160334/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13234437/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13234437/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13234437/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pa14_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_1.fastq /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pa14/ERR3642743_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pa14/ERR3642743_quant/logs
# [2021-01-15 18:16:26.889] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:16:26.889] [jointLog] [info] parsing read library format
# [2021-01-15 18:16:26.889] [jointLog] [info] There is 1 library.
# [2021-01-15 18:16:26.941] [jointLog] [info] Loading Quasi index
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pa14_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_1.fastq /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pa14/ERR3642743_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pa14/ERR3642743_quant/logs
# [2021-01-15 18:16:27.013] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:16:27.013] [jointLog] [info] parsing read library format
# [2021-01-15 18:16:27.013] [jointLog] [info] There is 1 library.
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pa14_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_1.fastq /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pa14/ERR3642743_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pa14/ERR3642743_quant/logs
# [2021-01-15 18:16:27.126] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:16:27.126] [jointLog] [info] parsing read library format
# [2021-01-15 18:16:27.126] [jointLog] [info] There is 1 library.
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# [2021-01-15 18:16:27.179] [jointLog] [info] Loading Quasi index
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pa14_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pa14/SRR13160334_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pa14/SRR13160334_quant/logs
# [2021-01-15 18:16:27.238] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:16:27.238] [jointLog] [info] parsing read library format
# [2021-01-15 18:16:27.238] [jointLog] [info] There is 1 library.
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# [2021-01-15 18:16:27.288] [jointLog] [info] Loading Quasi index
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pa14_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pa14/SRR13160334_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pa14/SRR13160334_quant/logs
# [2021-01-15 18:16:27.372] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:16:27.372] [jointLog] [info] parsing read library format
# [2021-01-15 18:16:27.372] [jointLog] [info] There is 1 library.
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# [2021-01-15 18:16:27.425] [jointLog] [info] Loading Quasi index
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pa14_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pa14/SRR13160334_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pa14/SRR13160334_quant/logs
# [2021-01-15 18:16:27.488] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:16:27.488] [jointLog] [info] parsing read library format
# [2021-01-15 18:16:27.488] [jointLog] [info] There is 1 library.
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# [2021-01-15 18:16:27.540] [jointLog] [info] Loading Quasi index
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pa14_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pa14/SRR13234437_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pa14/SRR13234437_quant/logs
# [2021-01-15 18:16:27.618] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:16:27.618] [jointLog] [info] parsing read library format
# [2021-01-15 18:16:27.618] [jointLog] [info] There is 1 library.
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# [2021-01-15 18:16:27.670] [jointLog] [info] Loading Quasi index
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pa14_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pa14/SRR13234437_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pa14/SRR13234437_quant/logs
# [2021-01-15 18:16:27.734] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:16:27.734] [jointLog] [info] parsing read library format
# [2021-01-15 18:16:27.734] [jointLog] [info] There is 1 library.
# [2021-01-15 18:16:27.789] [jointLog] [info] Loading Quasi index
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/pa14_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_pa14/SRR13234437_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_pa14/SRR13234437_quant/logs
# [2021-01-15 18:16:27.848] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:16:27.848] [jointLog] [info] parsing read library format
# [2021-01-15 18:16:27.848] [jointLog] [info] There is 1 library.
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# [2021-01-15 18:16:27.898] [jointLog] [info] Loading Quasi index
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-5-c553169aaa59> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '-s $paths.PA14_QUANT $paths.FASTQ_DIR $paths.PA14_INDEX', '\nfor FILE_PATH in $2/*;\ndo\n\n# get file name\nsample_name=`basename ${FILE_PATH}`\n\n# remove extension from file name\nsample_name="${sample_name%_*}"\n\n# get base path\nbase_name=${FILE_PATH%/*}\n\necho "Processing sample ${base_name}/${sample_name}/*"\n\nsalmon quant -i $3 \\\n             -l A \\\n             -r ${base_name}/${sample_name}/* \\\n             -o $1/${sample_name}_quant\ndone\n')
#
# ~/anaconda3/envs/core_acc/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2379             with self.builtin_trap:
#    2380                 args = (magic_arg_s, cell)
# -> 2381                 result = fn(*args, **kwargs)
#    2382             return result
#    2383
#
# ~/anaconda3/envs/core_acc/lib/python3.7/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# ~/anaconda3/envs/core_acc/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda3/envs/core_acc/lib/python3.7/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\nfor FILE_PATH in $2/*;\ndo\n\n# get file name\nsample_name=`basename ${FILE_PATH}`\n\n# remove extension from file name\nsample_name="${sample_name%_*}"\n\n# get base path\nbase_name=${FILE_PATH%/*}\n\necho "Processing sample ${base_name}/${sample_name}/*"\n\nsalmon quant -i $3 \\\n             -l A \\\n             -r ${base_name}/${sample_name}/* \\\n             -o $1/${sample_name}_quant\ndone\n'' returned non-zero exit status 1.

# %% [markdown]
# #### Get quants using phage reference

# %%
os.makedirs(paths.PHAGE_QUANT, exist_ok=True)

# %%
# %%bash -s $paths.PHAGE_QUANT $paths.FASTQ_DIR $paths.PHAGE_INDEX
#
# for FILE_PATH in $2/*;
# do
#
# # get file name
# sample_name=`basename ${FILE_PATH}`
#
# # remove extension from file name
# sample_name="${sample_name%_*}"
#
# # get base path
# base_name=${FILE_PATH%/*}
#
# echo "Processing sample ${base_name}/${sample_name}/*"
#
# salmon quant -i $3 \
#              -l A \
#              -r ${base_name}/${sample_name}/* \
#              -o $1/${sample_name}_quant
# done
# Out:
# Processing sample /home/alexandra/ncbi/public/fastq_phage/ERR3642743/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/ERR3642743/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/ERR3642743/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13160334/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13160334/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13160334/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13234437/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13234437/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# Processing sample /home/alexandra/ncbi/public/fastq_phage/SRR13234437/*
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/phage_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_1.fastq /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_phage/ERR3642743_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_phage/ERR3642743_quant/logs
# [2021-01-15 18:23:16.611] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:23:16.611] [jointLog] [info] parsing read library format
# [2021-01-15 18:23:16.611] [jointLog] [info] There is 1 library.
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# [2021-01-15 18:23:16.694] [jointLog] [info] Loading Quasi index
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/phage_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_1.fastq /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_phage/ERR3642743_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_phage/ERR3642743_quant/logs
# [2021-01-15 18:23:16.784] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:23:16.784] [jointLog] [info] parsing read library format
# [2021-01-15 18:23:16.784] [jointLog] [info] There is 1 library.
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# [2021-01-15 18:23:16.836] [jointLog] [info] Loading Quasi index
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/phage_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_1.fastq /home/alexandra/ncbi/public/fastq_phage/ERR3642743/ERR3642743_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_phage/ERR3642743_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_phage/ERR3642743_quant/logs
# [2021-01-15 18:23:16.903] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:23:16.903] [jointLog] [info] parsing read library format
# [2021-01-15 18:23:16.903] [jointLog] [info] There is 1 library.
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# [2021-01-15 18:23:16.956] [jointLog] [info] Loading Quasi index
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/phage_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_phage/SRR13160334_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_phage/SRR13160334_quant/logs
# [2021-01-15 18:23:17.024] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:23:17.024] [jointLog] [info] parsing read library format
# [2021-01-15 18:23:17.024] [jointLog] [info] There is 1 library.
# [2021-01-15 18:23:17.079] [jointLog] [info] Loading Quasi index
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/phage_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_phage/SRR13160334_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_phage/SRR13160334_quant/logs
# [2021-01-15 18:23:17.189] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:23:17.189] [jointLog] [info] parsing read library format
# [2021-01-15 18:23:17.189] [jointLog] [info] There is 1 library.
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# [2021-01-15 18:23:17.241] [jointLog] [info] Loading Quasi index
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/phage_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13160334/SRR13160334_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_phage/SRR13160334_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_phage/SRR13160334_quant/logs
# [2021-01-15 18:23:17.303] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:23:17.303] [jointLog] [info] parsing read library format
# [2021-01-15 18:23:17.303] [jointLog] [info] There is 1 library.
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# [2021-01-15 18:23:17.353] [jointLog] [info] Loading Quasi index
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/phage_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_phage/SRR13234437_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_phage/SRR13234437_quant/logs
# [2021-01-15 18:23:17.431] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:23:17.431] [jointLog] [info] parsing read library format
# [2021-01-15 18:23:17.431] [jointLog] [info] There is 1 library.
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# [2021-01-15 18:23:17.482] [jointLog] [info] Loading Quasi index
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/phage_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_phage/SRR13234437_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_phage/SRR13234437_quant/logs
# [2021-01-15 18:23:17.571] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:23:17.571] [jointLog] [info] parsing read library format
# [2021-01-15 18:23:17.571] [jointLog] [info] There is 1 library.
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# [2021-01-15 18:23:17.622] [jointLog] [info] Loading Quasi index
# ### salmon (mapping-based) v0.11.2
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/alexandra/Documents/Data/Core_accessory/phage_index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_1.fastq /home/alexandra/ncbi/public/fastq_phage/SRR13234437/SRR13234437_2.fastq }
# ### [ output ] => { /home/alexandra/ncbi/public/quants_phage/SRR13234437_quant }
# Logs will be written to /home/alexandra/ncbi/public/quants_phage/SRR13234437_quant/logs
# [2021-01-15 18:23:17.691] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-15 18:23:17.691] [jointLog] [info] parsing read library format
# [2021-01-15 18:23:17.691] [jointLog] [info] There is 1 library.
# Exception : [rapidjson internal assertion failure: IsObject()]
# salmon quant was invoked improperly.
# For usage information, try salmon quant --help
# Exiting.
# [2021-01-15 18:23:17.742] [jointLog] [info] Loading Quasi index
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-7-31f18aeda906> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '-s $paths.PHAGE_QUANT $paths.FASTQ_DIR $paths.PHAGE_INDEX', '\nfor FILE_PATH in $2/*;\ndo\n\n# get file name\nsample_name=`basename ${FILE_PATH}`\n\n# remove extension from file name\nsample_name="${sample_name%_*}"\n\n# get base path\nbase_name=${FILE_PATH%/*}\n\necho "Processing sample ${base_name}/${sample_name}/*"\n\nsalmon quant -i $3 \\\n             -l A \\\n             -r ${base_name}/${sample_name}/* \\\n             -o $1/${sample_name}_quant\ndone\n')
#
# ~/anaconda3/envs/core_acc/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2379             with self.builtin_trap:
#    2380                 args = (magic_arg_s, cell)
# -> 2381                 result = fn(*args, **kwargs)
#    2382             return result
#    2383
#
# ~/anaconda3/envs/core_acc/lib/python3.7/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# ~/anaconda3/envs/core_acc/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda3/envs/core_acc/lib/python3.7/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\nfor FILE_PATH in $2/*;\ndo\n\n# get file name\nsample_name=`basename ${FILE_PATH}`\n\n# remove extension from file name\nsample_name="${sample_name%_*}"\n\n# get base path\nbase_name=${FILE_PATH%/*}\n\necho "Processing sample ${base_name}/${sample_name}/*"\n\nsalmon quant -i $3 \\\n             -l A \\\n             -r ${base_name}/${sample_name}/* \\\n             -o $1/${sample_name}_quant\ndone\n'' returned non-zero exit status 1.

# %% [markdown]
# ### Consolidate sample quantification to gene expression dataframe

# %%
# Read through all sample subdirectories in quant/
# Within each sample subdirectory, get quant.sf file
data_dir = paths.PAO1_QUANT

expression_pao1_df = pd.DataFrame(
    pd.read_csv(file, sep="\t", index_col=0)["TPM"].
    rename(file.parent.name.split("_")[0]) 
    for file in data_dir.rglob("*/quant.sf"))    

expression_pao1_df.head()

# %%
# Read through all sample subdirectories in quant/
# Within each sample subdirectory, get quant.sf file
data_dir = paths.PA14_QUANT

expression_pa14_df = pd.DataFrame(
    pd.read_csv(file, sep="\t", index_col=0)["TPM"].
    rename(file.parent.name.split("_")[0]) 
    for file in data_dir.rglob("*/quant.sf"))    

expression_pa14_df.head()

# %%
# Read through all sample subdirectories in quant/
# Within each sample subdirectory, get quant.sf file
data_dir = paths.PHAGE_QUANT

expression_phage_df = pd.DataFrame(
    pd.read_csv(file, sep="\t", index_col=0)["TPM"].
    rename(file.parent.name.split("_")[0]) 
    for file in data_dir.rglob("*/quant.sf"))    

expression_phage_df.head()

# %%
# Save gene expression data
expression_pao1_df.to_csv(paths.PAO1_GE, sep='\t')
expression_pa14_df.to_csv(paths.PA14_GE, sep='\t')
expression_phage_df.to_csv(paths.PHAGE_GE, sep='\t')

# %% [markdown]
# # Format summary tables
#
# This notebook inputs the summary tables for PAO1 and PA14 and formats it to be one table using transcriptional similarity values for PAO1-aligned genes and includes expression statistics for both PAO1-aligned and PA14-aligned genes

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import random
import pandas as pd
from scripts import paths, utils

random.seed(1)

# %%
# Input similarity scores and annotations filenames
# Since the results are similar we only need to look at the scores for one strain type
pao1_similarity_filename = "pao1_core_similarity_associations_final_spell.tsv"
pa14_similarity_filename = "pa14_core_similarity_associations_final_spell.tsv"

# %%
# Import df
pao1_similarity = pd.read_csv(pao1_similarity_filename, sep="\t", index_col=0, header=0)
pa14_similarity = pd.read_csv(pa14_similarity_filename, sep="\t", index_col=0, header=0)

# %%
print(pao1_similarity.shape)
pao1_similarity.head()
# Out:
# (5349, 16)
#         PA14 homolog id  Transcriptional similarity across strains  \
# PAO1 id
# PA0118       PA14_01440                                   0.290443
# PA1859       PA14_40440                                   0.143328
# PA3190       PA14_22980                                   0.257508
# PA1009       PA14_51280                                   0.549950
# PA1065       PA14_50620                                   0.329633
#
#                P-value Name label  mean expression  \
# PAO1 id
# PA0118   1.771504e-104  NaN   NaN        84.379666
# PA1859    5.986934e-26  NaN   NaN       106.687908
# PA3190    9.170620e-82  NaN   NaN      2974.728597
# PA1009    0.000000e+00  NaN   NaN       448.628362
# PA1065   9.188709e-136  NaN   NaN       105.604816
#
#          standard deviation expression  min expression  25% expression  \
# PAO1 id
# PA0118                       87.012773        0.000000       30.805250
# PA1859                       91.482549        0.000000       50.280627
# PA3190                     4619.591491        0.000000      477.708748
# PA1009                      387.755818       18.128903      238.075927
# PA1065                       85.534956        0.000000       47.418993
#
#          50% expression  75% expression  max expression  variance expression  \
# PAO1 id
# PA0118        56.083433       98.678794      743.594397         7.571223e+03
# PA1859        78.021322      118.345717      584.117921         8.369057e+03
# PA3190      1386.138060     3291.525419    41815.193043         2.134063e+07
# PA1009       370.338444      543.930949     5826.229102         1.503546e+05
# PA1065        82.907779      144.322724      707.184303         7.316229e+03
#
#          range expression                      pathways present  \
# PAO1 id
# PA0118         743.594397                                    []
# PA1859         584.117921                                    []
# PA3190       41815.193043  ['path:pae02010 : ABC transporters']
# PA1009        5808.100199                                    []
# PA1065         707.184303                                    []
#
#         Related acc genes
# PAO1 id
# PA0118                NaN
# PA1859                NaN
# PA3190                NaN
# PA1009                NaN
# PA1065                NaN

# %%
print(pa14_similarity.shape)
pa14_similarity.head()
# Out:
# (5347, 16)
#            PAO1 homolog id  Transcriptional similarity across strains  \
# PA14 id
# PA14_23690          PA3125                                   0.185094
# PA14_11480          PA4049                                   0.327795
# PA14_01150          PA0094                                   0.418704
# PA14_11460          PA4051                                   0.541759
# PA14_56780          PA4366                                   0.482227
#
#                   P-value  Name label  mean expression  \
# PA14 id
# PA14_23690   2.030432e-42   NaN   NaN        85.595452
# PA14_11480  3.869112e-134   NaN   NaN       198.132451
# PA14_01150  4.989573e-226   NaN   NaN       105.290577
# PA14_11460   0.000000e+00  thiL   NaN       234.395250
# PA14_56780  1.451201e-309  sodB   NaN      7781.835203
#
#             standard deviation expression  min expression  25% expression  \
# PA14 id
# PA14_23690                     101.121951        0.000000       25.546082
# PA14_11480                     121.601925        0.000000      125.119670
# PA14_01150                     111.218985        0.000000       39.297006
# PA14_11460                     177.782645       16.650153      110.935215
# PA14_56780                    7633.163594      412.593023     3450.004296
#
#             50% expression  75% expression  max expression  \
# PA14 id
# PA14_23690       51.093537      104.536787      709.117909
# PA14_11480      168.451503      230.506602     1084.278966
# PA14_01150       75.807135      124.150007      860.205738
# PA14_11460      188.025557      300.223243     1008.676242
# PA14_56780     5718.029115     8591.327252    72482.666616
#
#             variance expression  range expression  \
# PA14 id
# PA14_23690         1.022565e+04        709.117909
# PA14_11480         1.478703e+04       1084.278966
# PA14_01150         1.236966e+04        860.205738
# PA14_11460         3.160667e+04        992.026089
# PA14_56780         5.826519e+07      72070.073593
#
#                                    pathways present Related acc genes
# PA14 id
# PA14_23690                                       []               NaN
# PA14_11480                                       []               NaN
# PA14_01150                                       []               NaN
# PA14_11460  ['path:pau00730 : Thiamine metabolism']               NaN
# PA14_56780                                       []               NaN

# %%
# Select expression statistics for PA14-aligned data
pa14_subset = pa14_similarity[
    [
        "PAO1 homolog id",
        "mean expression",
        "standard deviation expression",
        "25% expression",
        "50% expression",
        "75% expression",
        "min expression",
        "max expression",
        "variance expression",
        "range expression",
        "pathways present",
        "Related acc genes",
    ]
].set_index("PAO1 homolog id")

# %%
print(pa14_subset.shape)
pa14_subset.head()
# Out:
# (5347, 11)
#                  mean expression  standard deviation expression  \
# PAO1 homolog id
# PA3125                 85.595452                     101.121951
# PA4049                198.132451                     121.601925
# PA0094                105.290577                     111.218985
# PA4051                234.395250                     177.782645
# PA4366               7781.835203                    7633.163594
#
#                  25% expression  50% expression  75% expression  \
# PAO1 homolog id
# PA3125                25.546082       51.093537      104.536787
# PA4049               125.119670      168.451503      230.506602
# PA0094                39.297006       75.807135      124.150007
# PA4051               110.935215      188.025557      300.223243
# PA4366              3450.004296     5718.029115     8591.327252
#
#                  min expression  max expression  variance expression  \
# PAO1 homolog id
# PA3125                 0.000000      709.117909         1.022565e+04
# PA4049                 0.000000     1084.278966         1.478703e+04
# PA0094                 0.000000      860.205738         1.236966e+04
# PA4051                16.650153     1008.676242         3.160667e+04
# PA4366               412.593023    72482.666616         5.826519e+07
#
#                  range expression                         pathways present  \
# PAO1 homolog id
# PA3125                 709.117909                                       []
# PA4049                1084.278966                                       []
# PA0094                 860.205738                                       []
# PA4051                 992.026089  ['path:pau00730 : Thiamine metabolism']
# PA4366               72070.073593                                       []
#
#                 Related acc genes
# PAO1 homolog id
# PA3125                        NaN
# PA4049                        NaN
# PA0094                        NaN
# PA4051                        NaN
# PA4366                        NaN

# %%
# Merge dataframes based on PAO1 gene id
all_similarity = pao1_similarity.merge(
    pa14_subset, left_index=True, right_index=True, suffixes=["_pao1", "_p14"]
)

# %%
print(all_similarity.shape)
all_similarity.head()
# Out:
# (5347, 27)
#        PA14 homolog id  Transcriptional similarity across strains  \
# PA0118      PA14_01440                                   0.290443
# PA1859      PA14_40440                                   0.143328
# PA3190      PA14_22980                                   0.257508
# PA1009      PA14_51280                                   0.549950
# PA1065      PA14_50620                                   0.329633
#
#               P-value Name label  mean expression_pao1  \
# PA0118  1.771504e-104  NaN   NaN             84.379666
# PA1859   5.986934e-26  NaN   NaN            106.687908
# PA3190   9.170620e-82  NaN   NaN           2974.728597
# PA1009   0.000000e+00  NaN   NaN            448.628362
# PA1065  9.188709e-136  NaN   NaN            105.604816
#
#         standard deviation expression_pao1  min expression_pao1  \
# PA0118                           87.012773             0.000000
# PA1859                           91.482549             0.000000
# PA3190                         4619.591491             0.000000
# PA1009                          387.755818            18.128903
# PA1065                           85.534956             0.000000
#
#         25% expression_pao1  50% expression_pao1  ...  \
# PA0118            30.805250            56.083433  ...
# PA1859            50.280627            78.021322  ...
# PA3190           477.708748          1386.138060  ...
# PA1009           238.075927           370.338444  ...
# PA1065            47.418993            82.907779  ...
#
#         standard deviation expression_p14  25% expression_p14  \
# PA0118                          80.368739           23.079151
# PA1859                          57.028168           51.071843
# PA3190                        5428.865874          682.520390
# PA1009                         282.615721          170.776065
# PA1065                          86.037792           40.856930
#
#         50% expression_p14  75% expression_p14 min expression_p14  \
# PA0118           38.107897           57.933632           0.000000
# PA1859           72.575326          105.626428           0.000000
# PA3190         2268.790469         5222.390596           0.000000
# PA1009          274.443598          462.828788          13.871988
# PA1065           74.832672          115.490996           3.104826
#
#        max expression_p14  variance expression_p14  range expression_p14  \
# PA0118         662.245143             6.459134e+03            662.245143
# PA1859         400.928716             3.252212e+03            400.928716
# PA3190       77365.371337             2.947258e+07          77365.371337
# PA1009        2095.679114             7.987165e+04           2081.807126
# PA1065        1253.535657             7.402502e+03           1250.430831
#
#                         pathways present_p14  Related acc genes_p14
# PA0118                                    []                    NaN
# PA1859                                    []                    NaN
# PA3190  ['path:pau02010 : ABC transporters']                    NaN
# PA1009                                    []                    NaN
# PA1065                                    []                    NaN
#
# [5 rows x 27 columns]

# %%
# Some manual checks
# all_similarity.loc[["PA0744", "PA2588"]]
# pao1_similarity.loc[["PA0744", "PA2588"]]

# %%
# Output
all_similarity.to_csv("all_core_similarity_associations_final_spell.tsv", sep="\t")

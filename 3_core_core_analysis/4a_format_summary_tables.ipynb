# %% [markdown]
# # Format summary tables
#
# This notebook inputs the summary tables for PAO1 and PA14 and formats it to be one table using transcriptional similarity values for PAO1-aligned genes and includes expression statistics for both PAO1-aligned and PA14-aligned genes

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import random
import pandas as pd
from scripts import paths, utils

random.seed(1)

# %%
# Input similarity scores and annotations filenames
# Since the results are similar we only need to look at the scores for one strain type
pao1_similarity_filename = "pao1_core_similarity_associations_final_spell.tsv"
pa14_similarity_filename = "pa14_core_similarity_associations_final_spell.tsv"

# %%
# Import df
pao1_similarity = pd.read_csv(pao1_similarity_filename, sep="\t", index_col=0, header=0)
pa14_similarity = pd.read_csv(pa14_similarity_filename, sep="\t", index_col=0, header=0)

# %%
print(pao1_similarity.shape)
pao1_similarity.head()
# Out:
# (5349, 16)
#         PA14 homolog id  Transcriptional similarity across strains  \
# PAO1 id
# PA2763       PA14_28370                                   0.223647
# PA0687       PA14_55430                                   0.186869
# PA0048       PA14_00600                                   0.172591
# PA2363       PA14_34100                                   0.397806
# PA1171       PA14_49280                                   0.422021
#
#                P-value   Name label  mean expression  \
# PAO1 id
# PA2763    1.285228e-61    NaN   NaN        19.694848
# PA0687    3.120286e-43   hxcS   NaN        50.518187
# PA0048    4.860103e-37    NaN   NaN        86.414619
# PA2363   2.600695e-202  hsiJ3   NaN       327.426738
# PA1171   4.773292e-230  sltB2   NaN       298.032395
#
#          standard deviation expression  min expression  25% expression  \
# PAO1 id
# PA2763                       24.743003        0.000000        5.391723
# PA0687                      124.934061        0.000000        2.059509
# PA0048                       96.944680        0.000000       25.523418
# PA2363                      370.231163        0.000000       69.472696
# PA1171                      158.892450       14.169995      193.150705
#
#          50% expression  75% expression  max expression  variance expression  \
# PAO1 id
# PA2763        12.263734       23.681063      278.097141           612.216209
# PA0687        10.258957       31.659012     1167.426739         15608.519591
# PA0048        53.040761      113.420860      823.451891          9398.270927
# PA2363       210.784639      457.708200     3176.807775        137071.114318
# PA1171       276.005155      374.746932     1019.941686         25246.810693
#
#          range expression                                   pathways present  \
# PAO1 id
# PA2763         278.097141                                                 []
# PA0687        1167.426739  ['KEGG-Pathway-pae03070: Bacterial secretion s...
# PA0048         823.451891                                                 []
# PA2363        3176.807775   ['KEGG-Module-M00334: Type VI secretion system']
# PA1171        1005.771691                                                 []
#
#         Related acc genes
# PAO1 id
# PA2763                NaN
# PA0687                NaN
# PA0048                NaN
# PA2363                NaN
# PA1171                NaN

# %%
print(pa14_similarity.shape)
pa14_similarity.head()
# Out:
# (5347, 16)
#            PAO1 homolog id  Transcriptional similarity across strains  \
# PA14 id
# PA14_54660          PA0744                                   0.416944
# PA14_30620          PA2588                                   0.494403
# PA14_68400          PA5178                                   0.520295
# PA14_38850          PA1983                                   0.239950
# PA14_04760          PA0363                                   0.465735
#
#                   P-value  Name label  mean expression  \
# PA14 id
# PA14_54660  5.865823e-224   NaN   NaN       803.543344
# PA14_30620   0.000000e+00   NaN   NaN       892.601508
# PA14_68400   0.000000e+00   NaN   NaN      3134.472215
# PA14_38850   6.754510e-71  exaB   NaN        35.467321
# PA14_04760  3.828645e-286  coaD   NaN       355.338340
#
#             standard deviation expression  min expression  25% expression  \
# PA14 id
# PA14_54660                    1081.817170       14.240564      142.068583
# PA14_30620                    1095.977874       15.326451      209.813434
# PA14_68400                    3559.745121       25.280375      695.070834
# PA14_38850                     219.499403        0.000000        0.000000
# PA14_04760                     255.923231       19.537134      198.752170
#
#             50% expression  75% expression  max expression  \
# PA14 id
# PA14_54660      414.380788      913.522137     6057.518156
# PA14_30620      484.465843     1002.523013     7104.684725
# PA14_68400     2015.410297     4014.206074    25298.790957
# PA14_38850        3.238127       11.433134     4543.642316
# PA14_04760      284.643548      436.779949     2042.651981
#
#             variance expression  range expression  \
# PA14 id
# PA14_54660         1.170328e+06       6043.277593
# PA14_30620         1.201168e+06       7089.358274
# PA14_68400         1.267179e+07      25273.510582
# PA14_38850         4.817999e+04       4543.642316
# PA14_04760         6.549670e+04       2023.114847
#
#                                              pathways present  \
# PA14 id
# PA14_54660                                                 []
# PA14_30620                                                 []
# PA14_68400                                                 []
# PA14_38850                                                 []
# PA14_04760  ['KEGG-Pathway-pae00770: Pantothenate and CoA ...
#
#            Related acc genes
# PA14 id
# PA14_54660               NaN
# PA14_30620               NaN
# PA14_68400               NaN
# PA14_38850               NaN
# PA14_04760               NaN

# %%
# Select expression statistics for PA14-aligned data
pa14_subset = pa14_similarity[
    [
        "PAO1 homolog id",
        "mean expression",
        "standard deviation expression",
        "25% expression",
        "50% expression",
        "75% expression",
        "min expression",
        "max expression",
        "variance expression",
        "range expression",
        "pathways present",
        "Related acc genes",
    ]
].set_index("PAO1 homolog id")

# %%
print(pa14_subset.shape)
pa14_subset.head()
# Out:
# (5347, 11)
#                  mean expression  standard deviation expression  \
# PAO1 homolog id
# PA0744                803.543344                    1081.817170
# PA2588                892.601508                    1095.977874
# PA5178               3134.472215                    3559.745121
# PA1983                 35.467321                     219.499403
# PA0363                355.338340                     255.923231
#
#                  25% expression  50% expression  75% expression  \
# PAO1 homolog id
# PA0744               142.068583      414.380788      913.522137
# PA2588               209.813434      484.465843     1002.523013
# PA5178               695.070834     2015.410297     4014.206074
# PA1983                 0.000000        3.238127       11.433134
# PA0363               198.752170      284.643548      436.779949
#
#                  min expression  max expression  variance expression  \
# PAO1 homolog id
# PA0744                14.240564     6057.518156         1.170328e+06
# PA2588                15.326451     7104.684725         1.201168e+06
# PA5178                25.280375    25298.790957         1.267179e+07
# PA1983                 0.000000     4543.642316         4.817999e+04
# PA0363                19.537134     2042.651981         6.549670e+04
#
#                  range expression  \
# PAO1 homolog id
# PA0744                6043.277593
# PA2588                7089.358274
# PA5178               25273.510582
# PA1983                4543.642316
# PA0363                2023.114847
#
#                                                   pathways present  \
# PAO1 homolog id
# PA0744                                                          []
# PA2588                                                          []
# PA5178                                                          []
# PA1983                                                          []
# PA0363           ['KEGG-Pathway-pae00770: Pantothenate and CoA ...
#
#                 Related acc genes
# PAO1 homolog id
# PA0744                        NaN
# PA2588                        NaN
# PA5178                        NaN
# PA1983                        NaN
# PA0363                        NaN

# %%
# Merge dataframes based on PAO1 gene id
all_similarity = pao1_similarity.merge(
    pa14_subset, left_index=True, right_index=True, suffixes=["_pao1", "_p14"]
)

# %%
print(all_similarity.shape)
all_similarity.head()
# Out:
# (5347, 27)
#        PA14 homolog id  Transcriptional similarity across strains  \
# PA2763      PA14_28370                                   0.223647
# PA0687      PA14_55430                                   0.186869
# PA0048      PA14_00600                                   0.172591
# PA2363      PA14_34100                                   0.397806
# PA1171      PA14_49280                                   0.422021
#
#               P-value   Name label  mean expression_pao1  \
# PA2763   1.285228e-61    NaN   NaN             19.694848
# PA0687   3.120286e-43   hxcS   NaN             50.518187
# PA0048   4.860103e-37    NaN   NaN             86.414619
# PA2363  2.600695e-202  hsiJ3   NaN            327.426738
# PA1171  4.773292e-230  sltB2   NaN            298.032395
#
#         standard deviation expression_pao1  min expression_pao1  \
# PA2763                           24.743003             0.000000
# PA0687                          124.934061             0.000000
# PA0048                           96.944680             0.000000
# PA2363                          370.231163             0.000000
# PA1171                          158.892450            14.169995
#
#         25% expression_pao1  50% expression_pao1  ...  \
# PA2763             5.391723            12.263734  ...
# PA0687             2.059509            10.258957  ...
# PA0048            25.523418            53.040761  ...
# PA2363            69.472696           210.784639  ...
# PA1171           193.150705           276.005155  ...
#
#         standard deviation expression_p14  25% expression_p14  \
# PA2763                          49.808029            7.991056
# PA0687                          75.514622            2.101597
# PA0048                          55.776274           11.637363
# PA2363                         745.908938           61.075563
# PA1171                         142.557564          129.126722
#
#         50% expression_p14  75% expression_p14 min expression_p14  \
# PA2763           16.560478           40.186283           0.000000
# PA0687            7.905863           25.592966           0.000000
# PA0048           24.351790           51.313567           0.000000
# PA2363          154.455248          391.919946           0.000000
# PA1171          206.885616          292.197842          24.874447
#
#        max expression_p14  variance expression_p14  range expression_p14  \
# PA2763         547.002967              2480.839706            547.002967
# PA0687         775.099584              5702.458064            775.099584
# PA0048         593.557573              3110.992780            593.557573
# PA2363       11227.048304            556380.143242          11227.048304
# PA1171        1057.094057             20322.659085           1032.219610
#
#                                      pathways present_p14  \
# PA2763                                                 []
# PA0687  ['KEGG-Pathway-pae03070: Bacterial secretion s...
# PA0048                                                 []
# PA2363   ['KEGG-Module-M00334: Type VI secretion system']
# PA1171                                                 []
#
#         Related acc genes_p14
# PA2763                    NaN
# PA0687                    NaN
# PA0048                    NaN
# PA2363                    NaN
# PA1171                    NaN
#
# [5 rows x 27 columns]

# %%
# Some manual checks
# all_similarity.loc[["PA0744", "PA2588"]]
# pao1_similarity.loc[["PA0744", "PA2588"]]

# %%
# Output
all_similarity.to_csv("all_core_similarity_associations_final_spell.tsv", sep="\t")
